# %% [markdown]
# # CNN 실습

# %%
import os
import numpy as np
import shutil

original_dataset_dir = 'C:\\Users\\Affinity\\Downloads\\best-artworks-of-all-time\\images\\images\\'

validation_dir = 'C:\\Users\\Affinity\\Documents\\img\\art\\art_genre_img\\validation'

test_dir = 'C:\\Users\\Affinity\\Documents\\img\\art\\art_genre_img\\test'

train_dir = 'C:\\Users\\Affinity\\Documents\\img\\art\\art_genre_img\\train'

l = os.listdir(original_dataset_dir)

# %%
#validation

for i in l:
    if (i == 'Paul_Gauguin' or
        i == 'Edvard_Munch' or
        i == 'Gustav_Klimt' or
        i == 'Mikhail_Vrubel'
       ):
        os.mkdir(validation_dir + '/Symbolism/' + i)
        fnames = [f'{i}_{j}.jpg' for j in range(1, 21)]
        for fname in fnames:
            src = os.path.join(original_dataset_dir+f'{i}', fname)
            dst = os.path.join(validation_dir + '/Symbolism/', fname)
            shutil.move(src, dst)
    if (i == 'Vincent_van_Gogh' or
        i == 'Henri_de_Toulouse-Lautrec' or
        i == 'Paul_Cezanne' or
        i == 'Georges_Seurat'
       ):
        os.mkdir(validation_dir + '/Post_Impressionism/' + i)
        fnames = [f'{i}_{j}.jpg' for j in range(1, 21)]
        for fname in fnames:
            src = os.path.join(original_dataset_dir+f'{i}', fname)
            dst = os.path.join(validation_dir + '/Post_Impressionism/', fnam
            shutil.move(src, dst)
            
    if (i == 'Hieronymus_Bosch' or
        i == 'Albrecht_Du_rer' or
        i == 'Pieter_Bruegel' or
        i == 'Jan_van_Eyck'
       ):
        os.mkdir(validation_dir + '/Northern_Renaissance/' + i)
        fnames = [f'{i}_{j}.jpg' for j in range(1, 21)]
        for fname in fnames:
            src = os.path.join(original_dataset_dir+f'{i}', fname)
            dst = os.path.join(validation_dir + '/Northern_Renaissance/', fname)
            shutil.move(src, dst)
            
    if (i == 'Claude_Monet' or
        i == 'Pierre-Auguste_Renoir' or
        i == 'Alfred_Sisley' or
        i == 'Edgar_Degas'
       ):
#        os.mkdir(validation_dir + '/Impressionism/' + i)
        fnames = [f'{i}_{j}.jpg' for j in range(1, 21)]
        for fname in fnames:
            src = os.path.join(original_dataset_dir+f'{i}', fname)
            dst = os.path.join(validation_dir + '/Impressionism/', fname)
            shutil.move(src, dst)
            
    if (i == 'Titian' or
        i == 'Leonardo_da_Vinci' or
        i == 'Raphael' or
        i == 'Michelangelo'
       ):
#        os.mkdir(validation_dir + '/High_Renaissance/' + i)
        fnames = [f'{i}_{j}.jpg' for j in range(1, 21)]
        for fname in fnames:
            src = os.path.join(original_dataset_dir+f'{i}', fname)
            dst = os.path.join(validation_dir + '/High_Renaissance/', fname)
            shutil.move(src, dst)
            
    if (i == 'Peter_Paul_Rubens' or
        i == 'Caravaggio' or
        i == 'Diego_Velazquez' or
        i == 'Rembrandt'
       ):
#        os.mkdir(validation_dir + '/Baroque/' + i)
        fnames = [f'{i}_{j}.jpg' for j in range(1, 21)]
        for fname in fnames:
            src = os.path.join(original_dataset_dir+f'{i}', fname)
            dst = os.path.join(validation_dir + '/Baroque/', fname)
            shutil.move(src, dst)

# %%
#test

for i in l:
    if (i == 'Paul_Gauguin' or
        i == 'Edvard_Munch' or
        i == 'Gustav_Klimt' or
        i == 'Mikhail_Vrubel'
       ):
#        os.mkdir(test_dir + '/Symbolism/' + i)
        fnames = [f'{i}_{j}.jpg' for j in range(21, 41)]
        for fname in fnames:
            src = os.path.join(original_dataset_dir+f'{i}', fname)
            dst = os.path.join(test_dir + '/Symbolism/', fname)
            shutil.move(src, dst)
    if (i == 'Vincent_van_Gogh' or
        i == 'Henri_de_Toulouse-Lautrec' or
        i == 'Paul_Cezanne' or
        i == 'Georges_Seurat'
       ):
#        os.mkdir(test_dir + '/Post_Impressionism/' + i)
        fnames = [f'{i}_{j}.jpg' for j in range(21, 41)]
        for fname in fnames:
            src = os.path.join(original_dataset_dir+f'{i}', fname)
            dst = os.path.join(test_dir + '/Post_Impressionism/', fname)
            shutil.move(src, dst)
            
    if (i == 'Hieronymus_Bosch' or
        i == 'Albrecht_Du_rer' or
        i == 'Pieter_Bruegel' or
        i == 'Jan_van_Eyck'
       ):
#        os.mkdir(test_dir + '/Northern_Renaissance/' + i)
        fnames = [f'{i}_{j}.jpg' for j in range(21, 41)]
        for fname in fnames:
            src = os.path.join(original_dataset_dir+f'{i}', fname)
            dst = os.path.join(test_dir + '/Northern_Renaissance/', fname)
            shutil.move(src, dst)
            
    if (i == 'Claude_Monet' or
        i == 'Pierre-Auguste_Renoir' or
        i == 'Alfred_Sisley' or
        i == 'Edgar_Degas'
       ):
#        os.mkdir(test_dir + '/Impressionism/' + i)
        fnames = [f'{i}_{j}.jpg' for j in range(21, 41)]
        for fname in fnames:
            src = os.path.join(original_dataset_dir+f'{i}', fname)
            dst = os.path.join(test_dir + '/Impressionism/', fname)
            shutil.move(src, dst)
            
    if (i == 'Titian' or
        i == 'Leonardo_da_Vinci' or
        i == 'Raphael' or
        i == 'Michelangelo'
       ):
#        os.mkdir(test_dir + '/High_Renaissance/' + i)
        fnames = [f'{i}_{j}.jpg' for j in range(21, 41)]
        for fname in fnames:
            src = os.path.join(original_dataset_dir+f'{i}', fname)
            dst = os.path.join(test_dir + '/High_Renaissance/', fname)
            shutil.move(src, dst)
            
    if (i == 'Peter_Paul_Rubens' or
        i == 'Caravaggio' or
        i == 'Diego_Velazquez' or
        i == 'Rembrandt'
       ):
#        os.mkdir(test_dir + '/Baroque/' + i)
        fnames = [f'{i}_{j}.jpg' for j in range(21, 41)]
        for fname in fnames:
            src = os.path.join(original_dataset_dir+f'{i}', fname)
            dst = os.path.join(test_dir + '/Baroque/', fname)
            shutil.move(src, dst)

# %%
#train

for i in l:
    if (i == 'Paul_Gauguin' or
        i == 'Edvard_Munch' or
        i == 'Gustav_Klimt' or
        i == 'Mikhail_Vrubel'
       ):
#        os.mkdir(test_dir + '/Symbolism/' + i)
        length = len(os.listdir(original_dataset_dir+f'{i}'))
    
        fnames = [f'{i}_{j}.jpg' for j in range(41, length)]
        for fname in fnames:
            src = os.path.join(original_dataset_dir+f'{i}', fname)
            dst = os.path.join(train_dir + '/Symbolism/', fname)
            shutil.copyfile(src, dst)
    if (i == 'Vincent_van_Gogh' or
        i == 'Henri_de_Toulouse-Lautrec' or
        i == 'Paul_Cezanne' or
        i == 'Georges_Seurat'
       ):
#        os.mkdir(test_dir + '/Post_Impressionism/' + i)
        length = len(os.listdir(original_dataset_dir+f'{i}'))
        fnames = [f'{i}_{j}.jpg' for j in range(41, length)]
        for fname in fnames:
            src = os.path.join(original_dataset_dir+f'{i}', fname)
            dst = os.path.join(train_dir + '/Post_Impressionism/', fname)
            shutil.copyfile(src, dst)
            
    if (i == 'Hieronymus_Bosch' or
        i == 'Albrecht_Du_rer' or
        i == 'Pieter_Bruegel' or
        i == 'Jan_van_Eyck'
       ):
#        os.mkdir(test_dir + '/Northern_Renaissance/' + i)
        length = len(os.listdir(original_dataset_dir+f'{i}'))
        fnames = [f'{i}_{j}.jpg' for j in range(41, length)]
        for fname in fnames:
            src = os.path.join(original_dataset_dir+f'{i}', fname)
            dst = os.path.join(train_dir + '/Northern_Renaissance/', fname)
            shutil.copyfile(src, dst)
            
    if (i == 'Claude_Monet' or
        i == 'Pierre-Auguste_Renoir' or
        i == 'Alfred_Sisley' or
        i == 'Edgar_Degas'
       ):
#        os.mkdir(test_dir + '/Impressionism/' + i)
        length = len(os.listdir(original_dataset_dir+f'{i}'))
        fnames = [f'{i}_{j}.jpg' for j in range(41, length)]
        for fname in fnames:
            src = os.path.join(original_dataset_dir+f'{i}', fname)
            dst = os.path.join(train_dir + '/Impressionism/', fname)
            shutil.copyfile(src, dst)
            
    if (i == 'Titian' or
        i == 'Leonardo_da_Vinci' or
        i == 'Raphael' or
        i == 'Michelangelo'
       ):
#        os.mkdir(test_dir + '/High_Renaissance/' + i)
        length = len(os.listdir(original_dataset_dir+f'{i}'))
        fnames = [f'{i}_{j}.jpg' for j in range(41, length)]
        for fname in fnames:
            src = os.path.join(original_dataset_dir+f'{i}', fname)
            dst = os.path.join(train_dir + '/High_Renaissance/', fname)
            shutil.copyfile(src, dst)
            
    if (i == 'Peter_Paul_Rubens' or
        i == 'Caravaggio' or
        i == 'Diego_Velazquez' or
        i == 'Rembrandt'
       ):
#        os.mkdir(test_dir + '/Baroque/' + i)
        length = len(os.listdir(original_dataset_dir+f'{i}'))
        fnames = [f'{i}_{j}.jpg' for j in range(41, length)]
        for fname in fnames:
            src = os.path.join(original_dataset_dir+f'{i}', fname)
            dst = os.path.join(train_dir + '/Baroque/', fname)
            shutil.copyfile(src, dst)

# %%
import tensorflow as tf


gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=0.333)


sess = tf.Session(config=tf.ConfigProto(gpu_options=gpu_options))

# %%
from keras.preprocessing.image import ImageDataGenerator


train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=90,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.7,
    zoom_range=[0.9, 2.2],
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='nearest'
)



train_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(100, 100),
    batch_size=20,
    class_mode='categorical'
)

validation_datagen = ImageDataGenerator(rescale=1./255)

validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=(100, 100),
    batch_size=20,
    class_mode='categorical'
)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(100, 100),
    batch_size=20,
    class_mode='categorical'
)
# Out:
# Found 3132 images belonging to 6 classes.
# Found 480 images belonging to 6 classes.
# Found 480 images belonging to 6 classes.

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout


model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu',
         input_shape=(100, 100, 3)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(6, activation='softmax'))

model.compile(loss='categorical_crossentropy',
             optimizer='adam',
             metrics=['acc'])
# Out:
# WARNING:tensorflow:From C:\Users\Affinity\.conda\envs\keras\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
history = model.fit_generator(
    train_generator,
    steps_per_epoch=100,
    epochs=300,
    validation_data=validation_generator,
    validation_steps=150
)
# Out:
# WARNING:tensorflow:From C:\Users\Affinity\.conda\envs\keras\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/300
# 100/100 [==============================] - 90s 902ms/step - loss: 2.1328 - acc: 0.3550 - val_loss: 2.0584 - val_acc: 0.2407
# Epoch 2/300
# 100/100 [==============================] - 90s 899ms/step - loss: 1.3758 - acc: 0.4655 - val_loss: 1.6696 - val_acc: 0.3133
# Epoch 3/300
# 100/100 [==============================] - 94s 936ms/step - loss: 1.1958 - acc: 0.5295 - val_loss: 1.9791 - val_acc: 0.2883
# Epoch 4/300
# 100/100 [==============================] - 93s 932ms/step - loss: 0.9194 - acc: 0.6705 - val_loss: 2.5419 - val_acc: 0.2977
# Epoch 5/300
# 100/100 [==============================] - 94s 944ms/step - loss: 0.6601 - acc: 0.7725 - val_loss: 2.5747 - val_acc: 0.3750
# Epoch 6/300
# ...

# %%
import matplotlib.pyplot as plt


acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-370eebbe4f58> in <module>
#       2
#       3
# ----> 4 acc = history.history['acc']
#       5 val_acc = history.history['val_acc']
#       6 loss = history.history['loss']
#
# NameError: name 'history' is not defined
